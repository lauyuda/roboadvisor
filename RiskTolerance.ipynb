# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
import copy 
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neural_network import MLPRegressor

#Libraries for Statistical Models
import statsmodels.api as sm

#Libraries for Saving the Model
from pickle import dump
from pickle import load

# %%
# load dataset
dataset = pd.read_excel('SCFP2009panel.xlsx')

# %%
#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
dataset.shape
# Out:
# (19285, 515)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#Average SP500 during 2007 and 2009
Average_SP500_2007=1478
Average_SP500_2009=948

#Risk Tolerance 2007
dataset['RiskFree07']= dataset['LIQ07'] + dataset['CDS07'] + dataset['SAVBND07'] + dataset['CASHLI07']
dataset['Risky07'] = dataset['NMMF07'] + dataset['STOCKS07'] + dataset['BOND07'] 
dataset['RT07'] = dataset['Risky07']/(dataset['Risky07']+dataset['RiskFree07'])

#Risk Tolerance 2009
dataset['RiskFree09']= dataset['LIQ09'] + dataset['CDS09'] + dataset['SAVBND09'] + dataset['CASHLI09']
dataset['Risky09'] = dataset['NMMF09'] + dataset['STOCKS09'] + dataset['BOND09'] 
dataset['RT09'] = dataset['Risky09']/(dataset['Risky09']+dataset['RiskFree09'])*\
                (Average_SP500_2009/Average_SP500_2007)

# %%
dataset2 = copy.deepcopy(dataset)  
dataset.head()
# Out:
#    YY1  Y1         WGT09  AGE07  AGECL07  EDUC07  EDCL07  MARRIED07  KIDS07  \
# 0    1  11  11668.134198     47        3      12       2          1       0
# 1    1  12  11823.456494     47        3      12       2          1       0
# 2    1  13  11913.228354     47        3      12       2          1       0
# 3    1  14  11929.394266     47        3      12       2          1       0
# 4    1  15  11917.722907     47        3      12       2          1       0
#
#    LIFECL07  ...  TRANSFOTHINCPCT  PSAVINGPCT  LEVERAGEPCT   I   RiskFree07  \
# 0         2  ...              0.0   93.125197   270.403054  57  7994.813847
# 1         2  ...              0.0   93.125197   249.593620  57  7994.813847
# 2         2  ...              0.0   93.125197   209.233358  57  7984.457871
# 3         2  ...              0.0   93.125197   209.273158  57  7984.457871
# 4         2  ...              0.0   93.125197   232.690767  57  7994.813847
#
#    Risky07  RT07  RiskFree09  Risky09      RT09
# 0      0.0   0.0       16000    17000  0.330422
# 1      0.0   0.0       19000    18000  0.312036
# 2      0.0   0.0       13000    12000  0.307876
# 3      0.0   0.0       25000    13000  0.219429
# 4      0.0   0.0       17000    12000  0.265410
#
# [5 rows x 521 columns]

# %%
dataset2['PercentageChange'] = np.abs(dataset2['RT09']/dataset2['RT07']-1)

# %%
#Checking for any null values and removing the null values'''
print('Null Values =',dataset2.isnull().values.any())
# Out:
# Null Values = True

# %%
# Drop the rows containing NA
dataset2=dataset2.dropna(axis=0)

dataset2=dataset2[~dataset2.isin([np.nan, np.inf, -np.inf]).any(1)]

#Checking for any null values and removing the null values'''
print('Null Values =',dataset2.isnull().values.any())
# Out:
# Null Values = False

# %%
sns.distplot(dataset2['RT07'], hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})

# %%
sns.distplot(dataset2['RT09'], hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})

# %%
dataset3 = copy.deepcopy(dataset2)

# %%
dataset3 = dataset3[dataset3['PercentageChange']<=.1]

# %%
dataset3['TrueRiskTolerance'] = (dataset3['RT07'] + dataset3['RT09'])/2

# %%
dataset3.drop(labels=['RT07', 'RT09'], axis=1, inplace=True)
dataset3.drop(labels=['PercentageChange'], axis=1, inplace=True)

# %% [markdown]
# - AGE: There are 6 age categories, where 1 represents age less than 35 and 6 represents age more than 75.
# - EDUC: There are 4 education categories, where 1 represents no high school and 4 represents college degree.
# - MARRIED: It represents marital status. There are two categories where 1 represents married and 2 represents unmarried.
# - OCCU: It represents occupation category. 1 represents managerial category and 4 represents unemployed.
# - KIDS: It represents number of kids.
# - NWCAT: It represents net worth category. There are 5 categories, where 1 net worth less than 25 percentile and 5 represents net worth more than 90th percentile.
# - INCCL: It represents income category. There are 5 categories, where 1 income less than 10,000 and 5 represents net worth more than 100,000
# - RISK: It represents the willingness to take risk on a scale of 1 to 4, where 1 represents highest level of willingness to take risk.

# %%
keep_list2 = ['AGE07','EDCL07','MARRIED07','KIDS07','OCCAT107','INCOME07','RISK07','NETWORTH07','TrueRiskTolerance']

drop_list2 = [col for col in dataset3.columns if col not in keep_list2]

dataset3.drop(labels=drop_list2, axis=1, inplace=True)

# %%
# correlation
correlation = dataset3.corr()
plt.figure(figsize=(15,15))
plt.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='Spectral')

# %%
# Scatterplot Matrix
from pandas.plotting import scatter_matrix
plt.figure(figsize=(16,16))
scatter_matrix(dataset3,figsize=(12,12))
plt.show()

# %%
Y= dataset3["TrueRiskTolerance"]
X = dataset3.loc[:, dataset3.columns != 'TrueRiskTolerance']
# scaler = StandardScaler().fit(X)
# rescaledX = scaler.transform(X)
validation_size = 0.2
seed = 3
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
# test options for regression
num_folds = 5
#scoring = 'neg_mean_squared_error'
#scoring ='neg_mean_absolute_error'
scoring = 'r2'

# %%
# spot check the algorithms
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
#Ensemble Models 
# Boosting methods
models.append(('ABR', AdaBoostRegressor()))
models.append(('GBR', GradientBoostingRegressor()))
# Bagging methods
models.append(('RFR', RandomForestRegressor()))
models.append(('ETR', ExtraTreesRegressor()))

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    #converted mean square error to positive. The lower the better
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.135136 (0.080960)
# LASSO: 0.041113 (0.037595)
# EN: 0.050371 (0.040484)
# KNN: 0.409171 (0.132426)
# CART: 0.662494 (0.183937)
# SVR: 0.103849 (0.082732)
# ABR: 0.422034 (0.052421)
# GBR: 0.673943 (0.067509)
# RFR: 0.728275 (0.099565)
# ETR: 0.778190 (0.062691)

# %%
# compare algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
fig.set_size_inches(15,8)
plt.show()

# %%
# 8. Grid search : RandomForestRegressor 
'''
n_estimators : integer, optional (default=10)
    The number of trees in the forest.
'''
param_grid = {'n_estimators': [50,100,150,200,250,300,350,400],
             'max_depth': [10, 15, 20, 25, 30, 35, 40],
             'max_features': ['auto', 'sqrt', 'log2']}
model = RandomForestRegressor()
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(X_train, Y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.762530 using {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.724103 (0.081734) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 50}
# 0.720781 (0.089987) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 100}
# 0.731485 (0.087324) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 150}
# 0.732050 (0.088065) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 200}
# 0.727108 (0.091413) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 250}
# 0.721989 (0.087299) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 300}
# 0.726502 (0.085582) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 350}
# 0.725816 (0.088888) with: {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 400}
# 0.748920 (0.047721) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.741103 (0.063138) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.736685 (0.063555) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.740460 (0.064046) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.735369 (0.065920) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.742822 (0.063948) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.743783 (0.064142) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.743092 (0.061673) with: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.730197 (0.071870) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}
# 0.743865 (0.062906) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# 0.730084 (0.064098) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 150}
# 0.739497 (0.070643) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# 0.739605 (0.066336) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 250}
# 0.736038 (0.065222) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 300}
# 0.739695 (0.065206) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 350}
# 0.736867 (0.064032) with: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 400}
# 0.732152 (0.082922) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 50}
# 0.729054 (0.089131) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 100}
# 0.741697 (0.083268) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 150}
# 0.725469 (0.093886) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 200}
# 0.729585 (0.092738) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 250}
# 0.739715 (0.084661) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 300}
# 0.733723 (0.086850) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 350}
# 0.736806 (0.089633) with: {'max_depth': 15, 'max_features': 'auto', 'n_estimators': 400}
# 0.746708 (0.059743) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.748543 (0.077360) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.756075 (0.069059) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.754097 (0.064414) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.759778 (0.065385) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.753771 (0.064624) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.754656 (0.065233) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.757325 (0.063699) with: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.742121 (0.057232) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 50}
# 0.734888 (0.075793) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 100}
# 0.751150 (0.066553) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 150}
# 0.751431 (0.069869) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 200}
# 0.747392 (0.058850) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 250}
# 0.756548 (0.067824) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 300}
# 0.746335 (0.071508) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 350}
# 0.748690 (0.066972) with: {'max_depth': 15, 'max_features': 'log2', 'n_estimators': 400}
# 0.727728 (0.098226) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 50}
# 0.730128 (0.080170) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 100}
# 0.739579 (0.091489) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 150}
# 0.733637 (0.089473) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 200}
# 0.732224 (0.093239) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 250}
# 0.741803 (0.087498) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 300}
# 0.738345 (0.086805) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 350}
# 0.730441 (0.086317) with: {'max_depth': 20, 'max_features': 'auto', 'n_estimators': 400}
# 0.740747 (0.056430) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.747043 (0.070436) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.748980 (0.074700) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.760621 (0.056364) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.752408 (0.066099) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.754882 (0.067209) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.759410 (0.064125) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.749820 (0.070722) with: {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.745371 (0.045923) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 50}
# 0.746391 (0.067045) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# 0.746766 (0.067662) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 150}
# 0.752051 (0.075655) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}
# 0.751575 (0.068186) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 250}
# 0.738041 (0.072430) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 300}
# 0.755584 (0.065728) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 350}
# 0.749043 (0.068581) with: {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 400}
# 0.718767 (0.092565) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 50}
# 0.737731 (0.090324) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 100}
# 0.740374 (0.080159) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 150}
# 0.729753 (0.086030) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 200}
# 0.732855 (0.090797) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 250}
# 0.730507 (0.088556) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 300}
# 0.735826 (0.087639) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 350}
# 0.730583 (0.087251) with: {'max_depth': 25, 'max_features': 'auto', 'n_estimators': 400}
# 0.751634 (0.052584) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.756268 (0.060041) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.751096 (0.061976) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.757086 (0.068947) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.750864 (0.072574) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.758919 (0.065197) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.755549 (0.058366) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.752535 (0.066370) with: {'max_depth': 25, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.742640 (0.064305) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 50}
# 0.746824 (0.064065) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 100}
# 0.747333 (0.067941) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 150}
# 0.754434 (0.066965) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 200}
# 0.748003 (0.065594) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 250}
# 0.751014 (0.063938) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 300}
# 0.752885 (0.070873) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 350}
# 0.749859 (0.068326) with: {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 400}
# 0.724406 (0.092194) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 50}
# 0.732514 (0.077989) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 100}
# 0.728144 (0.097680) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 150}
# 0.738518 (0.082628) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 200}
# 0.732732 (0.087242) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 250}
# 0.739070 (0.090837) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 300}
# 0.735314 (0.090837) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 350}
# 0.734001 (0.088824) with: {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 400}
# 0.749047 (0.060270) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.752844 (0.058921) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.761151 (0.068409) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.753923 (0.071731) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.752218 (0.072046) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.757018 (0.061376) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.756483 (0.064091) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.762530 (0.063570) with: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.756342 (0.068438) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 50}
# 0.748684 (0.072937) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 100}
# 0.749764 (0.070103) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 150}
# 0.749463 (0.067523) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 200}
# 0.749531 (0.071530) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 250}
# 0.750850 (0.069599) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 300}
# 0.749759 (0.070438) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 350}
# 0.758275 (0.063415) with: {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 400}
# 0.722177 (0.095883) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 50}
# 0.742647 (0.077409) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 100}
# 0.736629 (0.085236) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 150}
# 0.739876 (0.085053) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 200}
# 0.734935 (0.087205) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 250}
# 0.731268 (0.091189) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 300}
# 0.737905 (0.089514) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 350}
# 0.735549 (0.087377) with: {'max_depth': 35, 'max_features': 'auto', 'n_estimators': 400}
# 0.750701 (0.067854) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.758232 (0.064708) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.760311 (0.067975) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.747557 (0.068962) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.760275 (0.067428) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.755813 (0.064301) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.756201 (0.060537) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.754202 (0.066670) with: {'max_depth': 35, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.749552 (0.065410) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 50}
# 0.742140 (0.067099) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 100}
# 0.752169 (0.067195) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 150}
# 0.744409 (0.070275) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 200}
# 0.749310 (0.074748) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 250}
# 0.751608 (0.062962) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 300}
# 0.749866 (0.069277) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 350}
# 0.750274 (0.065009) with: {'max_depth': 35, 'max_features': 'log2', 'n_estimators': 400}
# 0.721666 (0.081810) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 50}
# 0.732594 (0.077587) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 100}
# 0.738288 (0.087956) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 150}
# 0.733879 (0.086358) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 200}
# 0.740719 (0.087413) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 250}
# 0.733626 (0.095873) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 300}
# 0.727530 (0.090761) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 350}
# 0.735524 (0.090450) with: {'max_depth': 40, 'max_features': 'auto', 'n_estimators': 400}
# 0.753620 (0.063680) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 50}
# 0.759482 (0.060378) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.752410 (0.064970) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.756215 (0.064868) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.753433 (0.066538) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.759779 (0.055372) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.756463 (0.069571) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 350}
# 0.754428 (0.066376) with: {'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.748716 (0.075036) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 50}
# 0.746963 (0.079836) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 100}
# 0.751890 (0.070171) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 150}
# 0.750342 (0.072827) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 200}
# 0.753800 (0.069991) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 250}
# 0.747615 (0.072133) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 300}
# 0.747277 (0.065168) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 350}
# 0.750966 (0.065733) with: {'max_depth': 40, 'max_features': 'log2', 'n_estimators': 400}

# %%
grid_result.best_params_
# Out:
# {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 400}

# %%
# prepare model
model = RandomForestRegressor(max_depth = 15, max_features = 'sqrt', n_estimators = 250)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=15, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=250, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
predictions_train = model.predict(X_train)
print(mean_squared_error(Y_train, predictions_train))
print(r2_score(Y_train, predictions_train))
# Out:
# 0.001130186841527502
# 0.9655571039293696

# %%
# estimate accuracy on validation set
# transform the validation dataset
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
#rescaledValidationX = scaler.transform(X_validation)
predictions = model.predict(X_validation)
print(mean_squared_error(Y_validation, predictions))
print(r2_score(Y_validation, predictions))

# %%
import pandas as pd
import numpy as np
model = RandomForestRegressor(max_depth = 15, max_features = 'sqrt', n_estimators = 250, n_jobs=-1)
model.fit(X_train,Y_train)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
# Save Model Using Pickle
from pickle import dump
from pickle import load

# save the model to disk
filename = 'final_model.sav'
dump(model, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = load(open(filename, 'rb'))
# estimate accuracy on validation set
predictions = loaded_model.predict(X_validation)
result = mean_squared_error(Y_validation, predictions)
print(r2_score(Y_validation, predictions))
print(result)
